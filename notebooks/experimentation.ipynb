# %% [markdown]
# # Multilingual Legal Semantic Retrieval
#
# Use this notebook to inspect cases, rebuild embeddings, and compare semantic retrieval with BM25.

# %%
from src.retriever import LegalSemanticRetriever
from src.evaluator import evaluate_all_queries

retriever = LegalSemanticRetriever()
retriever.retrieve('છેતરપિંડી કેસ', language='gu', top_k=3)

# %%
evaluate_all_queries(retriever)
